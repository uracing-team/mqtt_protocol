# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/iggym/Documents/URacing Team/TelemetryData_10230136787177318441/TelemetryData_10230136787177318441.csv", header=0, low_memory=False)

# %%
df.tail(1)
# Out:
#          sessionTime  frameIdentifier  pilot_index  worldPositionX  \
# 1180639   3092.51074            65176           19      -805.82227
#
#          worldPositionY  worldPositionZ  worldVelocityX  worldVelocityY  \
# 1180639         0.12108     -1011.11804        73.12712         0.38642
#
#          worldVelocityZ  worldForwardDirX  ...  ersDeployedThisLap  \
# 1180639        10.47222             32432  ...          3791229.25
#
#          carPosition  currentLapTime  currentLapNum  lapDistance  \
# 1180639            1         79.9232             36   4523.29688
#
#          totalDistance  pitStatus  sector  driverStatus  resultStatus
# 1180639    162909.1875        NaN       2      on track        active
#
# [1 rows x 56 columns]

# %%
print(3092.51074/60)
# Out:
# 51.54184566666667

# %%
pilot_10 = df[df.pilot_index==10]

# %%
pilot_10.shape
# Out:
# (59032, 56)

# %%
pilot_10.sessionTime.max()
# Out:
# 3092.51074

# %%
pilot_10.tail(1)
# Out:
#          sessionTime  frameIdentifier  pilot_index  worldPositionX  \
# 1180630   3092.51074            65176           10         86.8092
#
#          worldPositionY  worldPositionZ  worldVelocityX  worldVelocityY  \
# 1180630         2.06245       -33.04312         9.45375        -0.27915
#
#          worldVelocityZ  worldForwardDirX  ...  ersDeployedThisLap  \
# 1180630       -46.98124              6461  ...         1618968.875
#
#          carPosition  currentLapTime  currentLapNum  lapDistance  \
# 1180630            5        43.40771             36    2510.8125
#
#          totalDistance  pitStatus  sector  driverStatus  resultStatus
# 1180630   160896.70312        NaN       1      on track        active
#
# [1 rows x 56 columns]

# %%
pilot_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59032 entries, 10 to 1180630
# Data columns (total 56 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   sessionTime              59032 non-null  float64
#  1   frameIdentifier          59032 non-null  int64
#  2   pilot_index              59032 non-null  int64
#  3   worldPositionX           59032 non-null  float64
#  4   worldPositionY           59032 non-null  float64
#  5   worldPositionZ           59032 non-null  float64
#  6   worldVelocityX           59032 non-null  float64
#  7   worldVelocityY           59032 non-null  float64
#  8   worldVelocityZ           59032 non-null  float64
#  9   worldForwardDirX         59032 non-null  int64
#  10  worldForwardDirY         59032 non-null  int64
#  11  worldForwardDirZ         59032 non-null  int64
#  12  worldRightDirX           59032 non-null  int64
#  13  worldRightDirY           59032 non-null  int64
# ...

# %%
pilot_10.memory_usage(index=False)
# Out:
# Index                      472256
# sessionTime                472256
# frameIdentifier            472256
# pilot_index                472256
# worldPositionX             472256
# worldPositionY             472256
# worldPositionZ             472256
# worldVelocityX             472256
# worldVelocityY             472256
# worldVelocityZ             472256
# worldForwardDirX           472256
# worldForwardDirY           472256
# worldForwardDirZ           472256
# worldRightDirX             472256
# worldRightDirY             472256
# worldRightDirZ             472256
# gForceLateral              472256
# gForceLongitudinal         472256
# gForceVertical             472256
# yaw                        472256
# pitch                      472256
# roll                       472256
# speed                      472256
# throttle                   472256
# steer                      472256
# brake                      472256
# clutch                     472256
# ...

# %%
df2 = pd.read_csv("data/processed_data.csv", header=0)

# %%
df2.tail()
# Out:
#        sessiontime  pilot_index  worldpositionz  speed  throttle    steer  \
# 59027   3092.30054           10       -23.49174    163   0.70432  0.00123
# 59028   3092.35059           10       -25.72190    165   0.78331 -0.00000
# 59029   3092.41064           10       -28.42525    167   0.87765  0.00123
# 59030   3092.46069           10       -30.71815    169   0.95651  0.00302
# 59031   3092.51074           10       -33.04312    172   1.00000  0.00349
#
#        brake  gear  enginerpm  enginetemperature  fuelintank  currentlaptime  \
# 59027    0.0     4      10048                 89     1.30474        43.19836
# 59028    0.0     4      10177                 89     1.30314        43.24833
# 59029    0.0     4      10355                 89     1.30116        43.30801
# 59030    0.0     4      10525                 89     1.29947        43.35789
# 59031    0.0     4      10701                 89     1.29775        43.40771
#
# ...

# %%
lap_6 = df2[df2.currentlapnum == 6]

# %%
lap_6.to_csv("data/lap_6.csv", index=False)

# %%
lap_6.head()
# Out:
#       sessiontime  pilot_index  worldpositionz  speed  throttle    steer  \
# 9222    482.48828           10     -1017.67377    257   1.00000  0.00174
# 9223    482.53799           10     -1017.15240    257   0.97932  0.00578
# 9224    482.58841           10     -1016.61981    258   1.00000  0.00508
# 9225    482.63965           10     -1016.07434    259   1.00000  0.00000
# 9226    482.69040           10     -1015.52911    260   1.00000 -0.00276
#
#       brake  gear  enginerpm  enginetemperature  fuelintank  currentlaptime  \
# 9222    0.0     6      11802                 89    50.97413         0.01955
# 9223    0.0     7      11058                 89    50.97377         0.06906
# 9224    0.0     7      10456                 89    50.97199         0.11937
# 9225    0.0     7      10448                 89    50.97024         0.17046
# 9226    0.0     7      10489                 89    50.96849         0.22141
#
#       currentlapnum  lapdistance  totaldistance  worldpositionx  \
# ...
